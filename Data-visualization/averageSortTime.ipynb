# %%
import json
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
sorts = ["Bubble",  "Heap", "Insertion", "Merge", "Quick", "Selection", "Shell"]
averages = [26543.34 ,9529.373333, 35137.35333, 21991.44, 9686.653333, 58760.7, 15066.04667]
ax.bar(sorts,averages)

#save file as png
output_file_path =  '../Data-visualization/Graphs/AveragesBarGraph.png'
plt.savefig(output_file_path)

plt.show()
